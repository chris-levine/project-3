# %%
# Import the dependencies.
from pathlib import Path
from sqlalchemy import create_engine, text
import pandas as pd
from pprint import pprint


# Create a reference to the file. 
database_path = Path("./Resources/Coin_Cardano.sqlite")

# %%
# Create an engine that can talk to the database
engine = create_engine(f"sqlite:///{database_path}")
conn=engine.connect()

# %%
data = pd.read_sql("SELECT * FROM Cardano", conn)
# Preview the Data
data.head()
# Out:
#   SNo     Name Symbol                 Date                  High  \
# 0   1  Cardano    ADA  2017-10-02 23:59:59  0.030087700113654137
# 1   2  Cardano    ADA  2017-10-03 23:59:59   0.02742519974708557
# 2   3  Cardano    ADA  2017-10-04 23:59:59  0.022806299850344658
# 3   4  Cardano    ADA  2017-10-05 23:59:59  0.022153599187731743
# 4   5  Cardano    ADA  2017-10-06 23:59:59    0.0215418990701437
#
#                     Low                  Open                 Close  \
# 0   0.01996929943561554   0.02460700087249279   0.02593179978430271
# 1   0.02068989910185337  0.025756599381566048   0.02081580087542534
# 2  0.020864099264144897  0.020864099264144897  0.021931499242782593
# 3   0.02085929922759533  0.021951299160718918  0.021488700062036514
# 4  0.018359700217843056  0.021358899772167206  0.018539100885391235
#
#       Volume        Marketcap
# 0  5.76413E7   6.2889905178E8
# 1  1.69978E7  5.39692714905E8
# 2  9000050.0  5.68619547504E8
# 3  5562510.0   5.5713904067E8
# ...

# %%
# Query All Records in the the Database

sql_statement = "SELECT * FROM Cardano"
with engine.begin() as conn:
    response = conn.exec_driver_sql(sql_statement).all()
    pprint(response)
# Out:
# [('1', 'Cardano', 'ADA', '2017-10-02 23:59:59', '0.030087700113654137', '0.01996929943561554', '0.02460700087249279', '0.02593179978430271', '5.76413E7', '6.2889905178E8'),
#  ('2', 'Cardano', 'ADA', '2017-10-03 23:59:59', '0.02742519974708557', '0.02068989910185337', '0.025756599381566048', '0.02081580087542534', '1.69978E7', '5.39692714905E8'),
#  ('3', 'Cardano', 'ADA', '2017-10-04 23:59:59', '0.022806299850344658', '0.020864099264144897', '0.020864099264144897', '0.021931499242782593', '9000050.0', '5.68619547504E8'),
#  ('4', 'Cardano', 'ADA', '2017-10-05 23:59:59', '0.022153599187731743', '0.02085929922759533', '0.021951299160718918', '0.021488700062036514', '5562510.0', '5.5713904067E8'),
#  ('5', 'Cardano', 'ADA', '2017-10-06 23:59:59', '0.0215418990701437', '0.018359700217843056', '0.021358899772167206', '0.018539100885391235', '7780710.0', '4.80664553411E8'),
# ...

# %%
# save path to the dataset as a variable
cardao_csv_path=Path("./Resources/coin_Cardano.csv")

# %%
# use panadas to read the data
cardano_df=pd.read_csv(cardao_csv_path)
cardano_df.head()
# Out:
#    SNo     Name Symbol                 Date      High       Low      Open  \
# 0    1  Cardano    ADA  2017-10-02 23:59:59  0.030088  0.019969  0.024607
# 1    2  Cardano    ADA  2017-10-03 23:59:59  0.027425  0.020690  0.025757
# 2    3  Cardano    ADA  2017-10-04 23:59:59  0.022806  0.020864  0.020864
# 3    4  Cardano    ADA  2017-10-05 23:59:59  0.022154  0.020859  0.021951
# 4    5  Cardano    ADA  2017-10-06 23:59:59  0.021542  0.018360  0.021359
#
#       Close      Volume     Marketcap
# 0  0.025932  57641300.0  6.288991e+08
# 1  0.020816  16997800.0  5.396927e+08
# 2  0.021931   9000050.0  5.686195e+08
# 3  0.021489   5562510.0  5.571390e+08
# 4  0.018539   7780710.0  4.806646e+08

# %%
cardano_df.describe()
# Out:
#                SNo         High          Low         Open        Close  \
# count  1374.000000  1374.000000  1374.000000  1374.000000  1374.000000
# mean    687.500000     0.269807     0.239710     0.255287     0.256313
# std     396.783946     0.433523     0.380928     0.408456     0.409691
# min       1.000000     0.021050     0.017620     0.018414     0.018539
# 25%     344.250000     0.047565     0.044601     0.045898     0.045947
# 50%     687.500000     0.090274     0.083164     0.086867     0.087002
# 75%    1030.750000     0.194519     0.172442     0.181374     0.183379
# max    1374.000000     2.461766     2.013285     2.300190     2.309113
#
#              Volume     Marketcap
# count  1.374000e+03  1.374000e+03
# mean   8.934183e+08  7.603454e+09
# std    2.107653e+09  1.303878e+10
# min    1.739460e+06  4.806646e+08
# 25%    5.014830e+07  1.191263e+09
# 50%    1.186742e+08  2.270889e+09
# 75%    4.875977e+08  5.174547e+09
# max    1.914198e+10  7.377224e+10

# %%
count_high=cardano_df["High"].value_counts()
print(count_high)
# Out:
# High
# 0.030088    1
# 0.033057    1
# 0.036239    1
# 0.036597    1
# 0.036595    1
#            ..
# 0.042547    1
# 0.043364    1
# 0.043665    1
# 0.043940    1
# 1.456887    1
# Name: count, Length: 1374, dtype: int64

# %%
cardano_df["High"].mean()
# Out:
# 0.26980675437353635

# %%
cardano_df["High"].sum()
# Out:
# 370.7144805092389

# %%
cardano_df["Average Price"]=(cardano_df["High"] + cardano_df["Low"])/2

cardano_df
# Out:
#        SNo     Name Symbol                 Date      High       Low      Open  \
# 0        1  Cardano    ADA  2017-10-02 23:59:59  0.030088  0.019969  0.024607
# 1        2  Cardano    ADA  2017-10-03 23:59:59  0.027425  0.020690  0.025757
# 2        3  Cardano    ADA  2017-10-04 23:59:59  0.022806  0.020864  0.020864
# 3        4  Cardano    ADA  2017-10-05 23:59:59  0.022154  0.020859  0.021951
# 4        5  Cardano    ADA  2017-10-06 23:59:59  0.021542  0.018360  0.021359
# ...    ...      ...    ...                  ...       ...       ...       ...
# 1369  1370  Cardano    ADA  2021-07-02 23:59:59  1.394397  1.286607  1.332942
# 1370  1371  Cardano    ADA  2021-07-03 23:59:59  1.441714  1.359664  1.394152
# 1371  1372  Cardano    ADA  2021-07-04 23:59:59  1.493717  1.382153  1.404008
# 1372  1373  Cardano    ADA  2021-07-05 23:59:59  1.461221  1.379284  1.461221
# 1373  1374  Cardano    ADA  2021-07-06 23:59:59  1.456887  1.393282  1.404712
#
# ...

# %%
total_volum=cardano_df["Volume"].sum()
total_volum
# Out:
# 1227556776052.6357

# %%
cardano_df["Volume %"] = (cardano_df["Volume"]/total_volum)*100
cardano_df.head()
# Out:
#    SNo     Name Symbol                 Date      High       Low      Open  \
# 0    1  Cardano    ADA  2017-10-02 23:59:59  0.030088  0.019969  0.024607
# 1    2  Cardano    ADA  2017-10-03 23:59:59  0.027425  0.020690  0.025757
# 2    3  Cardano    ADA  2017-10-04 23:59:59  0.022806  0.020864  0.020864
# 3    4  Cardano    ADA  2017-10-05 23:59:59  0.022154  0.020859  0.021951
# 4    5  Cardano    ADA  2017-10-06 23:59:59  0.021542  0.018360  0.021359
#
#       Close      Volume     Marketcap   Average  Volume %  Average Price
# 0  0.025932  57641300.0  6.288991e+08  0.025028  0.004696       0.025028
# 1  0.020816  16997800.0  5.396927e+08  0.024058  0.001385       0.024058
# 2  0.021931   9000050.0  5.686195e+08  0.021835  0.000733       0.021835
# 3  0.021489   5562510.0  5.571390e+08  0.021506  0.000453       0.021506
# 4  0.018539   7780710.0  4.806646e+08  0.019951  0.000634       0.019951
