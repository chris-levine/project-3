# %%
# Import the dependencies.
from pathlib import Path
from sqlalchemy import create_engine, text
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt
# Create a reference to the file. 
database_path = Path("./transformed_tables/coin_XRP.sqlite")

# %%
# Create an engine that can talk to the database
engine = create_engine(f"sqlite:///{database_path}")
conn=engine.connect()

# %%
data = pd.read_sql("SELECT * FROM xrp", conn)
# Preview the Data
data.head()
# Out:
#   SNo name symbol        date            daily_high              daily_low  \
# 0   1  XRP    XRP  2013-08-05   0.00597984017804265   0.005612660199403763
# 1   2  XRP    XRP  2013-08-06  0.005661020055413246   0.004628609865903854
# 2   3  XRP    XRP  2013-08-07   0.00468201981857419   0.004332609940320253
# 3   4  XRP    XRP  2013-08-08  0.004424029961228371   0.004175289999693632
# 4   5  XRP    XRP  2013-08-09  0.004366680048406124  0.0042526801116764545
#
#               open_price           close_price volume      marketcap  \
# 0   0.005874780006706715  0.005612660199403763      0    43879157.32
# 1  0.0056367600336670876  0.004680419806391001      0  36591007.7403
# 2   0.004669229965656996  0.004417319782078266      0   34534120.936
# 3    0.00439665000885725  0.004254170227795839      0  33258632.2164
# 4   0.004257250111550093  0.004291119985282421      0  33547503.2442
#
#   daily_percent_change liquidity_ratio              true_range  \
# ...

# %%
# save path to the old csv dataset as a variable
xrp_csv_path=Path("./Resources/coin_XRP.csv")
# use panadas to read the data
xrp_df=pd.read_csv(xrp_csv_path)
xrp_df.head()
# Out:
#    SNo Name Symbol                 Date      High       Low      Open  \
# 0    1  XRP    XRP  2013-08-05 23:59:59  0.005980  0.005613  0.005875
# 1    2  XRP    XRP  2013-08-06 23:59:59  0.005661  0.004629  0.005637
# 2    3  XRP    XRP  2013-08-07 23:59:59  0.004682  0.004333  0.004669
# 3    4  XRP    XRP  2013-08-08 23:59:59  0.004424  0.004175  0.004397
# 4    5  XRP    XRP  2013-08-09 23:59:59  0.004367  0.004253  0.004257
#
#       Close  Volume     Marketcap
# 0  0.005613     0.0  4.387916e+07
# 1  0.004680     0.0  3.659101e+07
# 2  0.004417     0.0  3.453412e+07
# 3  0.004254     0.0  3.325863e+07
# 4  0.004291     0.0  3.354750e+07

# %%
# save path to the new csv dataset as a variable
xrp_csv_path=Path("./new_CSV_files/new_xrp.csv")
# use panadas to read the data
xrp_df=pd.read_csv(xrp_csv_path)
xrp_df.head()
# Out:
#    SNo name symbol        date  daily_high  daily_low  open_price  \
# 0    1  XRP    XRP  2013-08-05    0.005980   0.005613    0.005875
# 1    2  XRP    XRP  2013-08-06    0.005661   0.004629    0.005637
# 2    3  XRP    XRP  2013-08-07    0.004682   0.004333    0.004669
# 3    4  XRP    XRP  2013-08-08    0.004424   0.004175    0.004397
# 4    5  XRP    XRP  2013-08-09    0.004367   0.004253    0.004257
#
#    close_price  volume     marketcap  daily_percent_change  liquidity_ratio  \
# 0     0.005613     0.0  4.387916e+07             -4.670153              0.0
# 1     0.004680     0.0  3.659101e+07            -20.432787              0.0
# 2     0.004417     0.0  3.453412e+07             -5.702783              0.0
# 3     0.004254     0.0  3.325863e+07             -3.349179              0.0
# 4     0.004291     0.0  3.354750e+07              0.789301              0.0
#
#    true_range  average_true_range  volatility_ratio  \
# 0    0.000367            0.000367          1.000000
# ...

# %%
# Query All Records in the the Database

sql_statement = "SELECT * FROM xrp"
with engine.begin() as conn:
    response = conn.exec_driver_sql(sql_statement).all()
    pprint(response)
# Out:
# [('1', 'XRP', 'XRP', '2013-08-05', '0.00597984017804265', '0.005612660199403763', '0.005874780006706715', '0.005612660199403763', '0', '43879157.32', '-4.6701527972564065', '0', '0.0003671799786388874', '0.0003671799786388874', '1', '6.1402975281368555'),
#  ('2', 'XRP', 'XRP', '2013-08-06', '0.005661020055413246', '0.004628609865903854', '0.0056367600336670876', '0.004680419806391001', '0', '36591007.7403', '-20.432787374547626', '0', '0.0010324101895093918', '0.0006997950840741396', '1.4753035752963555', '18.237175975417514'),
#  ('3', 'XRP', 'XRP', '2013-08-07', '0.00468201981857419', '0.004332609940320253', '0.004669229965656996', '0.004417319782078266', '0', '34534120.936', '-5.702783497829777', '0', '0.00034940987825393677', '0.0005830000154674053', '0.5993308215846381', '7.4628022048899'),
# ...

# %%
xrp_df.set_index("date")
five_rows=data.head(5)
five_rows
# Out:
#   SNo name symbol        date            daily_high              daily_low  \
# 0   1  XRP    XRP  2013-08-05   0.00597984017804265   0.005612660199403763
# 1   2  XRP    XRP  2013-08-06  0.005661020055413246   0.004628609865903854
# 2   3  XRP    XRP  2013-08-07   0.00468201981857419   0.004332609940320253
# 3   4  XRP    XRP  2013-08-08  0.004424029961228371   0.004175289999693632
# 4   5  XRP    XRP  2013-08-09  0.004366680048406124  0.0042526801116764545
#
#               open_price           close_price volume      marketcap  \
# 0   0.005874780006706715  0.005612660199403763      0    43879157.32
# 1  0.0056367600336670876  0.004680419806391001      0  36591007.7403
# 2   0.004669229965656996  0.004417319782078266      0   34534120.936
# 3    0.00439665000885725  0.004254170227795839      0  33258632.2164
# 4   0.004257250111550093  0.004291119985282421      0  33547503.2442
#
#   daily_percent_change liquidity_ratio              true_range  \
# ...
